# %%
import string
import pickle
import pandas as pd
import numpy as np
import seaborn
from matplotlib import pyplot as plt
# %matplotlib inline


from sklearn.ensemble import RandomForestClassifier
from sklearn.cross_validation import cross_val_score

import sklearn
import sklearn.datasets
import sklearn.cross_validation
import sklearn.decomposition
import sklearn.grid_search
import sklearn.neighbors
import sklearn.metrics

# %% [markdown]
# ## 3. Making a Predictor

# %% [markdown]
# #### 3.1 Tuning the Dataframe

# %%
with open('data1000summarized.txt', 'rb') as handle:
  trainingData = pickle.loads(handle.read())

# %%
# make this into a function makeDataFrame
def makeDataFrame(index, trainingData):
    master_data = []
    for i in xrange(len(trainingData)):
        master_data.append(pd.DataFrame(dict(zip(index, trainingData[i])), columns = index))
    return master_data

# column names
index = ['games', 'kd', 'kda', 'creep slain', 'win rate', 'damage dealt', 'win']
nfeat = len(index)

training_df = pd.concat(makeDataFrame(index, trainingData))
training_df.head()
# Out:
#    games           kd           kda  creep slain    win rate   damage dealt  \
# 0     20     2.024691      3.851852   191.950000   60.000000  150044.250000
# 1     32     0.290155      2.585492    29.968750   46.875000   24365.625000
# 2    199     1.901031      3.072165   116.638191   57.788945  142592.361809
# 3      2     1.000000      3.000000   136.500000  100.000000  113699.000000
# 4      1  3000.000000  15000.000000    42.000000  100.000000   96997.000000
#
#     win
# 0  True
# 1  True
# 2  True
# 3  True
# 4  True

# %%
# fix the KDA (since realisitically the most kills you can get is 30)
def fixDataFrame(df, cname, SIZE, MAX_KILLS, MAX_ASSISTS):
    df[cname[0]] = [min(MAX_KILLS, x) for x in df[cname[1]]]
    df[cname[1]] = [min(MAX_KILLS + MAX_ASSISTS, x) for x in df[cname[1]]]
    
    # subset only games greater than 5 to avoid outliers
    df = df[df[cname[2]] > 2]

    # eliminate supports and jungler role (will expand on this)
    df = df[df[cname[3]] > 60]
    return df.iloc[0:SIZE]

carry_df = fixDataFrame(training_df, ['kda','kd','games','creep slain'], 200, 20, 20)
'''
# scale data to [0,1]
MAX_DAMAGE = max(carry_df['damage dealt'])
MAX_CREEP = max(carry_df['creep slain'])
carry_df['damage dealt'] = carry_df['damage dealt']/MAX_DAMAGE
carry_df['creep slain'] = carry_df['creep slain']/MAX_CREEP
carry_df['win rate'] = carry_df['win rate']/100
'''
carry_df.head()
# Out:
#    games        kd       kda  creep slain   win rate   damage dealt    win
# 0     20  2.024691  2.024691   191.950000  60.000000  150044.250000   True
# 2    199  1.901031  1.901031   116.638191  57.788945  142592.361809   True
# 5      9  0.765957  0.765957    84.666667  55.555556   60719.555556  False
# 6     16  0.792453  0.792453   160.187500  37.500000  107157.187500  False
# 8     10  0.906250  0.906250   164.100000  40.000000  118119.000000  False

# %%
Y = [int(x) for x in carry_df['win']]
Y = np.asarray(Y)
X = carry_df.drop('win', 1)

# %% [markdown]
# #### Visualizations

# %%
def makeBoxPlot(df, x_feat, y_feat, names, y_label="", title=""):
    seaborn.boxplot([df[df[x_feat] == False][y_feat], carry_df[carry_df[x_feat] == True][y_feat]], names = names)
    plt.xlabel("win status")
    plt.ylabel(y_label)
    plt.title(title)
    plt.show()

# %%
for i in xrange(nfeat-1):
    makeBoxPlot(carry_df, index[nfeat-1], index[i], names = ['No','Yes'], 
            y_label = index[i], title = string.capitalize(index[i]) + ' of Winning and Losing Player')

# %% [markdown]
# Kd, kda, and win rate look slightly promising as factors to explain the differences. Games played is surprisingly an interesting factor. This suggests that people tend to win games better if they play a champion that they played frequently due to more experience.

# %% [markdown]
# #### 3.2 Correlation of Features

# %%
# Pairwise scatterplots of selected variables for correlation
pd.tools.plotting.scatter_matrix(carry_df[[u'kda', u'win rate', u'creep slain', u'damage dealt']])
plt.show()

plt.scatter(X['kda'], X['win rate'], c = Y, cmap = plt.cm.Set1, marker = '.')
plt.xlabel("kda")
plt.ylabel("win rate")
plt.title("Correlation of Two Variables")
plt.show()

plt.scatter(X['creep slain'], X['damage dealt'], c = Y, cmap = plt.cm.Set1, marker = '.')
plt.xlabel("creep slain")
plt.ylabel("damage dealt")
plt.title("Correlation of Two Variables")
plt.show()

plt.scatter(X['creep slain'], X['win rate'], c = Y, cmap = plt.cm.Set1, marker = '.')
plt.xlabel("creep slain")
plt.ylabel("win rate")
plt.title("Correlation of Two Variables")
plt.show()

# %% [markdown]
# #### 3.3 Building the Predictor

# %%
# get training and test sets
X_train, X_test, Y_train, Y_test = sklearn.cross_validation.train_test_split(X, Y, test_size=0.33, random_state=42)

# %%
scores_l = []
for i in xrange(40):
    forest = RandomForestClassifier(n_estimators = i+1) 
    scores_l.append(cross_val_score(forest, X_train, Y_train, cv=10))

seaborn.boxplot(scores_l, names = range(1,41))
plt.xlabel("Number of Trees")
plt.ylabel("Proportion Correctly Fitted")
plt.title("Cross Validation Score vs. Number of Trees in Random Forest")
plt.show()

# %% [markdown]
# #### Assessment of Model

# %%
# prediction on test set
forest = RandomForestClassifier(n_estimators = 20) 
forest.fit(X_train,Y_train)
pred = forest.predict(X_test)
pred_prob = forest.predict_proba(X_test)

print np.mean(pred == Y_test)
# Out:
# 0.545454545455

# %%
forest = RandomForestClassifier(n_estimators = 15) 
forest.fit(X,Y)
Z = forest.feature_importances_

seaborn.barplot(X.columns.values, Z)
plt.xticks(rotation = 45)
plt.title("Relative Importance of Features for Training Random Forest of 15 Trees")
plt.ylabel("Relative Ratio of Importance")
plt.show()

# %% [markdown]
# A prediction accuracy of 0.6 is not very convincing so we do the svd and see if there is a hidden pattern.

# %%
svd = sklearn.decomposition.TruncatedSVD(n_components=2, random_state=42)
X_pca = svd.fit_transform(X_train)

plt.scatter(X_pca[:,0], X_pca[:,1], c = Y_train, cmap = plt.cm.Set1)
plt.xlabel("first PC")
plt.ylabel("second PC")
plt.title("First 2 PCA of Digits Data Set")
plt.show()

# %% [markdown]
# There doesn't seem to be an easy way to distinguish the two groups from each other so a method such as SVM or KNN would not be viable

# %% [markdown]
# Therefore we decide to fix more covariates. Since league has 120 champions (characters that one can play), there are many variables that account for the inaccuracy of prediction. One of them is the difference of champions. For instance, champions that are classified as carries tend to do much more damage than others and spend more time destroying creep. What if we only collect and analyze data on one specific champion? The same playstyle of this champion will fix more data and better distingush a winner from a loser. We shall select three champions to analyze. Vayne and Ezreal which are both carries and Lee Sin which is a semi-carry. All 3 are fairly difficult champions that require practice to play well decently.

# %% [markdown]
# ## 4 Specific Champion Analysis

# %% [markdown]
# #### 4.1 What separates the great players from the good player?

# %% [markdown]
# #### a) Case Study: Ezreal

# %% [markdown]
# #### b) Case Study: Vayne

# %% [markdown]
# #### c) Case Study: Leesin
